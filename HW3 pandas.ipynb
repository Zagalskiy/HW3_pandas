# %% [markdown]
# # Задание 3. Pandas (HW)
# ### Используя библиотеку pandas (или аналоги), проанализировать как можно больше характеристик, влияющих на успеваемость студентов.
# Результат прислать в формате ссылки на Github с ноутбуком

# %%
# Импортируем необходимые библиотеки
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive/My Drive/data/')
# DF_name.to_csv('DF_name.csv', sep = ',', index = 'False')
# DF_name.csv "drive/My Drive/"
# Out:
# The kernel failed to start due to the missing module 'prompt_toolkit.formatted_text'. Consider installing this module.
#
# Нажмите <a href="https://aka.ms/kernelFailuresMissingModule">здесь</a> для получения дополнительных сведений.

# %% [markdown]
# ## Анализ вспомогательных таблиц

# %% [markdown]
# ### lectures.csv : метаданные для лекций, просмотренных студентами по мере их обучения.
#
# **lecture_id**: внешний ключ для столбца content_type_id в train.csv, если тип контента - лекция (1).
# **part**: раздел, к которому относится лекция.
# **tag**: один тег для каждой лекции. Значения тегов не представлены, но их достаточно для кластеризации лекций.
# **type_of**: краткое описание основной цели лекции.

# %%
# dfl = pd.read_csv('data/lectures.csv') # считываем данные из файла lectures.csv в датафрейм dfl
dfl = pd.read_csv('lectures.csv')
dfl.shape # выводим размерность датафрейма dfl

# %%
dfl.head() # выводим 5 первых строк датафрейма dfl
# Out:
#    lecture_id  tag  part           type_of
# 0          89  159     5           concept
# 1         100   70     1           concept
# 2         185   45     6           concept
# 3         192   79     5  solving question
# 4         317  156     5  solving question

# %%
dfl.describe() # выводим статистику датафрейма dfl
# Out:
#          lecture_id         tag        part
# count    418.000000  418.000000  418.000000
# mean   16983.401914   94.480861    4.267943
# std     9426.164660   53.586487    1.872424
# min       89.000000    0.000000    1.000000
# 25%     9026.250000   50.250000    2.000000
# 50%    17161.500000   94.500000    5.000000
# 75%    24906.250000  140.000000    6.000000
# max    32736.000000  187.000000    7.000000

# %%
dfl.isna().sum() # ищем недостающие значения датафрейма dfl
# Out:
# lecture_id    0
# tag           0
# part          0
# type_of       0
# dtype: int64

# %%
dfl.duplicated().sum() # ищем дубликаты - отсутствуют
# Out:
# 0

# %%
dfl.info() # выводим справку о кол-ве значений в каждом столбце и формате данных датафрейма dfl
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   lecture_id  418 non-null    int64
#  1   tag         418 non-null    int64
#  2   part        418 non-null    int64
#  3   type_of     418 non-null    object
# dtypes: int64(3), object(1)
# memory usage: 13.2+ KB

# %%
# Выводим распеределение внешних ключей по различным разделам лекций
dfl[['type_of', 'part', 'lecture_id']].groupby(['type_of','part'], as_index = False).count().sort_values(by = ['type_of', 'part'])
# Out:
#              type_of  part  lecture_id
# 0            concept     1          20
# 1            concept     2          18
# 2            concept     3           7
# 3            concept     4          19
# 4            concept     5          72
# 5            concept     6          63
# 6            concept     7          23
# 7          intention     2           7
# 8   solving question     1          34
# 9   solving question     2          31
# 10  solving question     3          12
# 11  solving question     4          12
# 12  solving question     5          69
# 13  solving question     6          19
# 14  solving question     7           9
# 15           starter     5           2
# 16           starter     6           1

# %%
# Явной связи тегов, разделов и описаний лекций не видно
sns.scatterplot(data = dfl, x = 'tag', y = 'part', hue = 'type_of')
# Out:
# <AxesSubplot: xlabel='tag', ylabel='part'>

# %%
# Явной связи тегов и описаний лекций не видно
sns.histplot(data = dfl, x = 'tag', hue = 'type_of')
# Out:
# <AxesSubplot: xlabel='tag', ylabel='Count'>

# %%
# Выводим связь разделов и описаний лекций: в первых 3-х разделах больше практики, в остальных - теории
sns.histplot(data = dfl, x = 'part', hue = 'type_of', bins = 7)
# Out:
# <AxesSubplot: xlabel='part', ylabel='Count'>

# %% [markdown]
# ### questions.csv : метаданные для заданных студентам вопросов.
#
# **question_id**: внешний ключ для столбца content_type_id в train.csv, если тип контента - вопрос (0).
# **bundle_id**: идентификатор совместного набора вопросов.
# **correct_answer**: правильный ответ на вопрос. Можно сравнить со столбцом user_answer в train.csv, чтобы проверить, верно ли ответил студент.
# **part**: соответствующий раздел теста TOEIC.
# **tags**: один или несколько подробных тегов для каждого вопроса. Значения тегов не представлены, но их достаточно для кластеризации вопросов.

# %%
dfq = pd.read_csv('data/questions.csv') # считываем данные из файла questions.csv в датафрейм dfq
dfq.shape # выводим размерность датафрейма dfq
# Out:
# (13523, 5)

# %%
dfq.head() # выводим 5 первых строк датафрейма dfq
# Out:
#    question_id  bundle_id  correct_answer  part            tags
# 0            0          0               0     1   51 131 162 38
# 1            1          1               1     1       131 36 81
# 2            2          2               0     1  131 101 162 92
# 3            3          3               0     1  131 149 162 29
# 4            4          4               3     1    131 5 162 38

# %%
dfq.describe() # выводим статистику датафрейма dfq
# Out:
#        question_id     bundle_id  correct_answer          part
# count  13523.00000  13523.000000    13523.000000  13523.000000
# mean    6761.00000   6760.510907        1.455298      4.264956
# std     3903.89818   3903.857783        1.149707      1.652553
# min        0.00000      0.000000        0.000000      1.000000
# 25%     3380.50000   3379.500000        0.000000      3.000000
# 50%     6761.00000   6761.000000        1.000000      5.000000
# 75%    10141.50000  10140.000000        3.000000      5.000000
# max    13522.00000  13522.000000        3.000000      7.000000

# %%
dfq.isna().sum() # ищем недостающие значения датафрейма dfq
# Out:
# question_id       0
# bundle_id         0
# correct_answer    0
# part              0
# tags              1
# dtype: int64

# %%
dfq[dfq.tags.isna()] # выводим недостающие значения в столбце тегов
# Out:
#        question_id  bundle_id  correct_answer  part tags
# 10033        10033      10033               2     6  NaN

# %%
dfq.duplicated().sum() # ищем дубликаты - отсутствуют
# Out:
# 0

# %%
dfq.info() # выводим справку о кол-ве значений в каждом столбце и формате данных датафрейма dfq
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13523 entries, 0 to 13522
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   question_id     13523 non-null  int64
#  1   bundle_id       13523 non-null  int64
#  2   correct_answer  13523 non-null  int64
#  3   part            13523 non-null  int64
#  4   tags            13522 non-null  object
# dtypes: int64(4), object(1)
# memory usage: 528.4+ KB

# %%
# Выводим кол-во значений внешних ключей, соответствующих каждому значению в столбце разделов
dfq[['part', 'question_id']].groupby(['part'], as_index = False).count()
# Out:
#    part  question_id
# 0     1          992
# 1     2         1647
# 2     3         1562
# 3     4         1439
# 4     5         5511
# 5     6         1212
# 6     7         1160

# %%
# Внешние ключи распределены практически равномерно по всем разделам, кроме 5
sns.histplot(data = dfq, x = 'part', bins = 7)
# Out:
# <AxesSubplot: xlabel='part', ylabel='Count'>

# %% [markdown]
# ## Анализ основной таблицы

# %% [markdown]
# ### train.csv : метаданные ответов на заданные студентам вопросы.
#
# **row_id**: (int64) идентификатор строки.
# **timestamp**: (int64) время в миллисекундах между этим взаимодействием со студентом и завершением первого события от данного студента.
# **user_id**: (int32) идентификатор студента.
# **content_id**: (int16) идентификатор взаимодействия со студентом.
# **content_type_id**: (int8) идентификатор типа контента. 0, если контентом был заданный студенту вопрос, 1 - просмотр студентом лекции.
# **task_container_id**: (int16) идентификатор набора вопросов или лекций. Например, студент может увидеть три вопроса подряд, прежде чем увидит пояснения к какому-либо из них. Все три вопроса будут иметь общий идентификатор набора.
# **user_answer**: (int8) ответ студента на вопрос, если они есть. Для лекций считать -1 как null.
# **answered_correctly**: (int8) был ли ответ студента на вопрос правильным. Для лекций считать -1 как null.
# **prior_question_elapsed_time**: (float32) среднее время в миллисекундах, затрачиваемое студентом для ответа на каждый вопрос из предыдущего набора вопросов, без учёта промежуточных лекций. Имеет значение null для первого набора вопросов или лекции.
# **prior_question_had_explanation**: (bool) увидел ли студент объяснение и правильный ответ после ответа на предыдущий набор вопросов, без учёта промежуточных лекций. Это значение является общим для одного набора вопросов и имеет значение null для первого набора вопросов или лекции. Как правило, первые несколько вопросов, увиденные студентом, были частью вводного диагностического теста и не получили никакой обратной связи.

# %%
df = pd.read_csv('data/train.csv', nrows = 1000000) # считываем 1000000 строк из файла train.csv в датафрейм df
df.shape # выводим размерность датафрейма df
# Out:
# (1000000, 10)

# %%
df.head() # выводим 5 первых строк датафрейма dfq
# Out:
#    row_id  timestamp  user_id  content_id  content_type_id  task_container_id  \
# 0       0          0      115        5692                0                  1
# 1       1      56943      115        5716                0                  2
# 2       2     118363      115         128                0                  0
# 3       3     131167      115        7860                0                  3
# 4       4     137965      115        7922                0                  4
#
#    user_answer  answered_correctly  prior_question_elapsed_time  \
# 0            3                   1                          NaN
# 1            2                   1                      37000.0
# 2            0                   1                      55000.0
# 3            0                   1                      19000.0
# 4            1                   1                      11000.0
#
#   prior_question_had_explanation
# 0                            NaN
# 1                          False
# 2                          False
# 3                          False
# 4                          False

# %% [markdown]
# ### Анализ числовых признаков

# %%
# Посмотрим на то, какие у нас есть категориальные и числовые столбцы
cat_columns = []
num_columns = []

for column_name in df.columns:
    if (df[column_name].dtypes == object):
        cat_columns += [column_name]
    else:
        num_columns += [column_name]

print('Категориальные данные:\t ',cat_columns, '\n Число столблцов =', len(cat_columns))
print('Числовые данные:\t ', num_columns, '\n Число столблцов =', len(num_columns))
# Out:
# Категориальные данные:	  ['prior_question_had_explanation']
#  Число столблцов = 1
# Числовые данные:	  ['row_id', 'timestamp', 'user_id', 'content_id', 'content_type_id', 'task_container_id', 'user_answer', 'answered_correctly', 'prior_question_elapsed_time']
#  Число столблцов = 9

# %%
df.describe() # выводим статистику датафрейма df
# Out:
#                row_id     timestamp       user_id      content_id  \
# count  1000000.000000  1.000000e+06  1.000000e+06  1000000.000000
# mean    499999.500000  7.344311e+09  1.017255e+07     5232.691523
# std     288675.278932  1.058693e+10  6.029234e+06     3882.323419
# min          0.000000  0.000000e+00  1.150000e+02        0.000000
# 25%     249999.750000  5.211669e+08  4.702585e+06     2057.000000
# 50%     499999.500000  2.824811e+09  9.678259e+06     5052.000000
# 75%     749999.250000  1.010186e+10  1.556872e+07     7421.000000
# max     999999.000000  7.809200e+10  2.094902e+07    32736.000000
#
#        content_type_id  task_container_id     user_answer  answered_correctly  \
# count   1000000.000000     1000000.000000  1000000.000000      1000000.000000
# mean          0.019907         806.105689        1.374784            0.617504
# std           0.139681        1025.887530        1.194168            0.525364
# min           0.000000           0.000000       -1.000000           -1.000000
# 25%           0.000000         109.000000        0.000000            0.000000
# 50%           0.000000         391.000000        1.000000            1.000000
# 75%           0.000000        1112.000000        3.000000            1.000000
# max           1.000000        7739.000000        3.000000            1.000000
#
#        prior_question_elapsed_time
# count                976277.000000
# mean                  25302.962693
# std                   19710.310227
# min                       0.000000
# 25%                   16000.000000
# 50%                   21000.000000
# 75%                   29666.000000
# max                  300000.000000

# %% [markdown]
# ### Рассмотрим гистограммы (распределение) значений по каждому числовому признаку (столбцу)

# %%
# Сначала столбцы с "большими" значениями
num_col_big = ['row_id', 'timestamp', 'user_id', 'content_id', 'task_container_id', 'prior_question_elapsed_time']
width = 2
height = int(np.ceil(len(num_col_big) / width))
fig, ax = plt.subplots(nrows = height, ncols = width, figsize = (10, 10))

for idx, column_name in enumerate(num_col_big):
    plt.subplot(height, width, idx + 1)
    sns.histplot(data = df, x = column_name, bins = 20)

# %%
# Затем столбцы с "маленькими" значениями
num_col_small = ['content_type_id', 'user_answer', 'answered_correctly']
width = 1
height = int(np.ceil(len(num_col_small) / width))
fig, ax = plt.subplots(nrows = height, ncols = width, figsize = (5, 10))

for idx, column_name in enumerate(num_col_small):
    plt.subplot(height, width, idx + 1)
    sns.histplot(data = df, x = column_name, bins = 5)

# %%
df.isna().sum() # ищем недостающие значения датафрейма df
# Out:
# row_id                                0
# timestamp                             0
# user_id                               0
# content_id                            0
# content_type_id                       0
# task_container_id                     0
# user_answer                           0
# answered_correctly                    0
# prior_question_elapsed_time       23723
# prior_question_had_explanation     3816
# dtype: int64

# %%
# Выводим недостающие значения в столбце времени ответа на каждый вопрос. 
# Обусловлено условием: имеет значение null для первого набора вопросов или лекции.
df[df.prior_question_elapsed_time.isna()]
# Out:
#         row_id   timestamp   user_id  content_id  content_type_id  \
# 0            0           0       115        5692                0
# 46          46           0       124        7900                0
# 76          76           0      2746        5273                0
# 89          89      653762      2746        6808                1
# 96          96           0      5382        5000                0
# ...        ...         ...       ...         ...              ...
# 999762  999762   207265143  20938253       26404                1
# 999790  999790   208152685  20938253       22362                1
# 999859  999859  1142327350  20938253        1731                1
# 999901  999901           0  20948951        6040                0
# 999952  999952           0  20949024        7900                0
#
#         task_container_id  user_answer  answered_correctly  \
# 0                       1            3                   1
# 46                      0            0                   1
# 76                      0            1                   0
# 89                     14           -1                  -1
# 96                      0            0                   1
# ...                   ...          ...                 ...
# 999762                308           -1                  -1
# 999790                336           -1                  -1
# 999859                406           -1                  -1
# 999901                  0            3                   0
# 999952                  0            0                   1
#
#         prior_question_elapsed_time prior_question_had_explanation
# 0                               NaN                            NaN
# 46                              NaN                            NaN
# 76                              NaN                            NaN
# 89                              NaN                          False
# 96                              NaN                            NaN
# ...                             ...                            ...
# 999762                          NaN                          False
# 999790                          NaN                          False
# 999859                          NaN                          False
# 999901                          NaN                            NaN
# 999952                          NaN                            NaN
#
# [23723 rows x 10 columns]

# %%
# Выводим недостающие значения в столбце просмотра объяснений и правильных ответов. 
# Обусловлено условием: имеет значение null для первого набора вопросов или лекции.
df[df.prior_question_had_explanation.isna()]
# Out:
#         row_id  timestamp   user_id  content_id  content_type_id  \
# 0            0          0       115        5692                0
# 46          46          0       124        7900                0
# 76          76          0      2746        5273                0
# 96          96          0      5382        5000                0
# 224        224          0      8623        3915                0
# ...        ...        ...       ...         ...              ...
# 998929  998929          0  20913319        6659                0
# 999345  999345          0  20913864        4790                0
# 999366  999366          0  20938253        7900                0
# 999901  999901          0  20948951        6040                0
# 999952  999952          0  20949024        7900                0
#
#         task_container_id  user_answer  answered_correctly  \
# 0                       1            3                   1
# 46                      0            0                   1
# 76                      0            1                   0
# 96                      0            0                   1
# 224                     0            3                   1
# ...                   ...          ...                 ...
# 998929                  0            1                   0
# 999345                  0            1                   1
# 999366                  0            2                   0
# 999901                  0            3                   0
# 999952                  0            0                   1
#
#         prior_question_elapsed_time prior_question_had_explanation
# 0                               NaN                            NaN
# 46                              NaN                            NaN
# 76                              NaN                            NaN
# 96                              NaN                            NaN
# 224                             NaN                            NaN
# ...                             ...                            ...
# 998929                          NaN                            NaN
# 999345                          NaN                            NaN
# 999366                          NaN                            NaN
# 999901                          NaN                            NaN
# 999952                          NaN                            NaN
#
# [3816 rows x 10 columns]

# %%
df.duplicated().sum() # ищем дубликаты - отсутствуют
# Out:
# 0

# %%
df.info() # выводим справку о кол-ве значений в каждом столбце и формате данных датафрейма df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   row_id                          1000000 non-null  int64
#  1   timestamp                       1000000 non-null  int64
#  2   user_id                         1000000 non-null  int64
#  3   content_id                      1000000 non-null  int64
#  4   content_type_id                 1000000 non-null  int64
#  5   task_container_id               1000000 non-null  int64
#  6   user_answer                     1000000 non-null  int64
#  7   answered_correctly              1000000 non-null  int64
#  8   prior_question_elapsed_time     976277 non-null   float64
#  9   prior_question_had_explanation  996184 non-null   object
# dtypes: float64(1), int64(8), object(1)
# memory usage: 76.3+ MB

# %% [markdown]
# ### Рассмотрим корреляцию числовых признаков

# %%
cm = sns.color_palette("vlag", as_cmap = True)
df_corr = df.loc[:,['row_id', 'timestamp', 'user_id', 'content_id', 'content_type_id', 'task_container_id', 'user_answer', 'answered_correctly', 'prior_question_elapsed_time']]
df_corr.corr().style.background_gradient(cmap = cm, vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_93ff0_row0_col0, #T_93ff0_row0_col2, #T_93ff0_row1_col1, #T_93ff0_row2_col0, #T_93ff0_row2_col2, #T_93ff0_row3_col3, #T_93ff0_row4_col4, #T_93ff0_row5_col5, #T_93ff0_row6_col6, #T_93ff0_row7_col7, #T_93ff0_row8_col8 {
#   background-color: #a9373b;
#   color: #f1f1f1;
# }
# #T_93ff0_row0_col1, #T_93ff0_row0_col3, #T_93ff0_row0_col6, #T_93ff0_row0_col7, #T_93ff0_row1_col0, #T_93ff0_row1_col2, #T_93ff0_row1_col6, #T_93ff0_row2_col1, #T_93ff0_row2_col3, #T_93ff0_row2_col6, #T_93ff0_row2_col7, #T_93ff0_row3_col0, #T_93ff0_row3_col2, #T_93ff0_row4_col5, #T_93ff0_row5_col4, #T_93ff0_row6_col0, #T_93ff0_row6_col1, #T_93ff0_row6_col2, #T_93ff0_row7_col0, #T_93ff0_row7_col2 {
#   background-color: #faf5f5;
#   color: #000000;
# }
# #T_93ff0_row0_col4, #T_93ff0_row1_col4, #T_93ff0_row2_col4, #T_93ff0_row4_col0, #T_93ff0_row4_col1, #T_93ff0_row4_col2, #T_93ff0_row5_col6, #T_93ff0_row6_col5, #T_93ff0_row6_col8, #T_93ff0_row7_col8, #T_93ff0_row8_col6, #T_93ff0_row8_col7 {
#   background-color: #faf5f4;
#   color: #000000;
# }
# #T_93ff0_row0_col5, #T_93ff0_row2_col5, #T_93ff0_row5_col0, #T_93ff0_row5_col2 {
#   background-color: #f2f0f2;
#   color: #000000;
# }
# #T_93ff0_row0_col8, #T_93ff0_row1_col8, #T_93ff0_row2_col8, #T_93ff0_row8_col0, #T_93ff0_row8_col1, #T_93ff0_row8_col2 {
#   background-color: #faf4f3;
#   color: #000000;
# }
# #T_93ff0_row1_col3, #T_93ff0_row3_col1 {
#   background-color: #faf3f2;
#   color: #000000;
# }
# #T_93ff0_row1_col5, #T_93ff0_row5_col1 {
#   background-color: #deb2b0;
#   color: #000000;
# }
# #T_93ff0_row1_col7, #T_93ff0_row7_col1 {
#   background-color: #faf3f3;
#   color: #000000;
# }
# #T_93ff0_row3_col4, #T_93ff0_row4_col3 {
#   background-color: #daa8a5;
#   color: #000000;
# }
# #T_93ff0_row3_col5, #T_93ff0_row5_col3 {
#   background-color: #f9eeed;
#   color: #000000;
# }
# #T_93ff0_row3_col6, #T_93ff0_row6_col3 {
#   background-color: #ebeaee;
#   color: #000000;
# }
# #T_93ff0_row3_col7, #T_93ff0_row7_col3 {
#   background-color: #d7dae4;
#   color: #000000;
# }
# #T_93ff0_row3_col8, #T_93ff0_row8_col3 {
#   background-color: #f1dddb;
#   color: #000000;
# }
# #T_93ff0_row4_col6, #T_93ff0_row6_col4 {
#   background-color: #c7cedc;
#   color: #000000;
# }
# #T_93ff0_row4_col7, #T_93ff0_row7_col4 {
#   background-color: #a7b6ce;
#   color: #000000;
# }
# #T_93ff0_row4_col8, #T_93ff0_row8_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_93ff0_row5_col7, #T_93ff0_row7_col5 {
#   background-color: #faf2f1;
#   color: #000000;
# }
# #T_93ff0_row5_col8, #T_93ff0_row8_col5 {
#   background-color: #f7f4f4;
#   color: #000000;
# }
# #T_93ff0_row6_col7, #T_93ff0_row7_col6 {
#   background-color: #f3e2e0;
#   color: #000000;
# }
# </style>
# <table id="T_93ff0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93ff0_level0_col0" class="col_heading level0 col0" >row_id</th>
#       <th id="T_93ff0_level0_col1" class="col_heading level0 col1" >timestamp</th>
#       <th id="T_93ff0_level0_col2" class="col_heading level0 col2" >user_id</th>
#       <th id="T_93ff0_level0_col3" class="col_heading level0 col3" >content_id</th>
#       <th id="T_93ff0_level0_col4" class="col_heading level0 col4" >content_type_id</th>
#       <th id="T_93ff0_level0_col5" class="col_heading level0 col5" >task_container_id</th>
#       <th id="T_93ff0_level0_col6" class="col_heading level0 col6" >user_answer</th>
#       <th id="T_93ff0_level0_col7" class="col_heading level0 col7" >answered_correctly</th>
#       <th id="T_93ff0_level0_col8" class="col_heading level0 col8" >prior_question_elapsed_time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93ff0_level0_row0" class="row_heading level0 row0" >row_id</th>
#       <td id="T_93ff0_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_93ff0_row0_col1" class="data row0 col1" >-0.000843</td>
#       <td id="T_93ff0_row0_col2" class="data row0 col2" >0.999057</td>
#       <td id="T_93ff0_row0_col3" class="data row0 col3" >-0.006783</td>
#       <td id="T_93ff0_row0_col4" class="data row0 col4" >0.004011</td>
#       <td id="T_93ff0_row0_col5" class="data row0 col5" >-0.071142</td>
#       <td id="T_93ff0_row0_col6" class="data row0 col6" >-0.002382</td>
#       <td id="T_93ff0_row0_col7" class="data row0 col7" >-0.015589</td>
#       <td id="T_93ff0_row0_col8" class="data row0 col8" >0.016242</td>
#     </tr>
#     <tr>
#       <th id="T_93ff0_level0_row1" class="row_heading level0 row1" >timestamp</th>
#       <td id="T_93ff0_row1_col0" class="data row1 col0" >-0.000843</td>
#       <td id="T_93ff0_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_93ff0_row1_col2" class="data row1 col2" >-0.001041</td>
#       <td id="T_93ff0_row1_col3" class="data row1 col3" >0.032189</td>
#       <td id="T_93ff0_row1_col4" class="data row1 col4" >0.007441</td>
#       <td id="T_93ff0_row1_col5" class="data row1 col5" >0.364525</td>
#       <td id="T_93ff0_row1_col6" class="data row1 col6" >-0.001796</td>
#       <td id="T_93ff0_row1_col7" class="data row1 col7" >0.027571</td>
#       <td id="T_93ff0_row1_col8" class="data row1 col8" >0.016144</td>
#     </tr>
#     <tr>
#       <th id="T_93ff0_level0_row2" class="row_heading level0 row2" >user_id</th>
#       <td id="T_93ff0_row2_col0" class="data row2 col0" >0.999057</td>
#       <td id="T_93ff0_row2_col1" class="data row2 col1" >-0.001041</td>
#       <td id="T_93ff0_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_93ff0_row2_col3" class="data row2 col3" >-0.007103</td>
#       <td id="T_93ff0_row2_col4" class="data row2 col4" >0.004102</td>
#       <td id="T_93ff0_row2_col5" class="data row2 col5" >-0.072862</td>
#       <td id="T_93ff0_row2_col6" class="data row2 col6" >-0.002361</td>
#       <td id="T_93ff0_row2_col7" class="data row2 col7" >-0.014776</td>
#       <td id="T_93ff0_row2_col8" class="data row2 col8" >0.016981</td>
#     </tr>
#     <tr>
#       <th id="T_93ff0_level0_row3" class="row_heading level0 row3" >content_id</th>
#       <td id="T_93ff0_row3_col0" class="data row3 col0" >-0.006783</td>
#       <td id="T_93ff0_row3_col1" class="data row3 col1" >0.032189</td>
#       <td id="T_93ff0_row3_col2" class="data row3 col2" >-0.007103</td>
#       <td id="T_93ff0_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_93ff0_row3_col4" class="data row3 col4" >0.420121</td>
#       <td id="T_93ff0_row3_col5" class="data row3 col5" >0.062908</td>
#       <td id="T_93ff0_row3_col6" class="data row3 col6" >-0.110374</td>
#       <td id="T_93ff0_row3_col7" class="data row3 col7" >-0.203327</td>
#       <td id="T_93ff0_row3_col8" class="data row3 col8" >0.149778</td>
#     </tr>
#     <tr>
#       <th id="T_93ff0_level0_row4" class="row_heading level0 row4" >content_type_id</th>
#       <td id="T_93ff0_row4_col0" class="data row4 col0" >0.004011</td>
#       <td id="T_93ff0_row4_col1" class="data row4 col1" >0.007441</td>
#       <td id="T_93ff0_row4_col2" class="data row4 col2" >0.004102</td>
#       <td id="T_93ff0_row4_col3" class="data row4 col3" >0.420121</td>
#       <td id="T_93ff0_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_93ff0_row4_col5" class="data row4 col5" >-0.013024</td>
#       <td id="T_93ff0_row4_col6" class="data row4 col6" >-0.283418</td>
#       <td id="T_93ff0_row4_col7" class="data row4 col7" >-0.438788</td>
#       <td id="T_93ff0_row4_col8" class="data row4 col8" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_93ff0_level0_row5" class="row_heading level0 row5" >task_container_id</th>
#       <td id="T_93ff0_row5_col0" class="data row5 col0" >-0.071142</td>
#       <td id="T_93ff0_row5_col1" class="data row5 col1" >0.364525</td>
#       <td id="T_93ff0_row5_col2" class="data row5 col2" >-0.072862</td>
#       <td id="T_93ff0_row5_col3" class="data row5 col3" >0.062908</td>
#       <td id="T_93ff0_row5_col4" class="data row5 col4" >-0.013024</td>
#       <td id="T_93ff0_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_93ff0_row5_col6" class="data row5 col6" >0.012135</td>
#       <td id="T_93ff0_row5_col7" class="data row5 col7" >0.039130</td>
#       <td id="T_93ff0_row5_col8" class="data row5 col8" >-0.043670</td>
#     </tr>
#     <tr>
#       <th id

# %% [markdown]
# ### Рассмотрим успеваемость студентов

# %%
# Добавляем столбец cor_ratio успеваемости (соотношения кол-ва правильных ответов к общему кол-ву ответов студентов)
df_corr['cor_ratio'] = df_corr.answered_correctly / df_corr.user_answer
# Выведем новую корреляцию числовых признаков
df_corr.corr().style.background_gradient(cmap = cm, vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_f1e54_row0_col0, #T_f1e54_row0_col2, #T_f1e54_row1_col1, #T_f1e54_row2_col0, #T_f1e54_row2_col2, #T_f1e54_row3_col3, #T_f1e54_row4_col4, #T_f1e54_row5_col5, #T_f1e54_row6_col6, #T_f1e54_row7_col7, #T_f1e54_row8_col8, #T_f1e54_row9_col9 {
#   background-color: #a9373b;
#   color: #f1f1f1;
# }
# #T_f1e54_row0_col1, #T_f1e54_row0_col3, #T_f1e54_row0_col6, #T_f1e54_row0_col7, #T_f1e54_row0_col9, #T_f1e54_row1_col0, #T_f1e54_row1_col2, #T_f1e54_row1_col6, #T_f1e54_row2_col1, #T_f1e54_row2_col3, #T_f1e54_row2_col6, #T_f1e54_row2_col7, #T_f1e54_row2_col9, #T_f1e54_row3_col0, #T_f1e54_row3_col2, #T_f1e54_row4_col5, #T_f1e54_row5_col4, #T_f1e54_row6_col0, #T_f1e54_row6_col1, #T_f1e54_row6_col2, #T_f1e54_row7_col0, #T_f1e54_row7_col2, #T_f1e54_row8_col9, #T_f1e54_row9_col0, #T_f1e54_row9_col2, #T_f1e54_row9_col8 {
#   background-color: #faf5f5;
#   color: #000000;
# }
# #T_f1e54_row0_col4, #T_f1e54_row1_col4, #T_f1e54_row2_col4, #T_f1e54_row4_col0, #T_f1e54_row4_col1, #T_f1e54_row4_col2, #T_f1e54_row5_col6, #T_f1e54_row6_col5, #T_f1e54_row6_col8, #T_f1e54_row7_col8, #T_f1e54_row8_col6, #T_f1e54_row8_col7 {
#   background-color: #faf5f4;
#   color: #000000;
# }
# #T_f1e54_row0_col5, #T_f1e54_row2_col5, #T_f1e54_row5_col0, #T_f1e54_row5_col2 {
#   background-color: #f2f0f2;
#   color: #000000;
# }
# #T_f1e54_row0_col8, #T_f1e54_row1_col8, #T_f1e54_row2_col8, #T_f1e54_row5_col9, #T_f1e54_row8_col0, #T_f1e54_row8_col1, #T_f1e54_row8_col2, #T_f1e54_row9_col5 {
#   background-color: #faf4f3;
#   color: #000000;
# }
# #T_f1e54_row1_col3, #T_f1e54_row1_col9, #T_f1e54_row3_col1, #T_f1e54_row9_col1 {
#   background-color: #faf3f2;
#   color: #000000;
# }
# #T_f1e54_row1_col5, #T_f1e54_row5_col1 {
#   background-color: #deb2b0;
#   color: #000000;
# }
# #T_f1e54_row1_col7, #T_f1e54_row7_col1 {
#   background-color: #faf3f3;
#   color: #000000;
# }
# #T_f1e54_row3_col4, #T_f1e54_row4_col3 {
#   background-color: #daa8a5;
#   color: #000000;
# }
# #T_f1e54_row3_col5, #T_f1e54_row5_col3 {
#   background-color: #f9eeed;
#   color: #000000;
# }
# #T_f1e54_row3_col6, #T_f1e54_row6_col3 {
#   background-color: #ebeaee;
#   color: #000000;
# }
# #T_f1e54_row3_col7, #T_f1e54_row7_col3 {
#   background-color: #d7dae4;
#   color: #000000;
# }
# #T_f1e54_row3_col8, #T_f1e54_row8_col3 {
#   background-color: #f1dddb;
#   color: #000000;
# }
# #T_f1e54_row3_col9, #T_f1e54_row9_col3 {
#   background-color: #f7ebea;
#   color: #000000;
# }
# #T_f1e54_row4_col6, #T_f1e54_row6_col4 {
#   background-color: #c7cedc;
#   color: #000000;
# }
# #T_f1e54_row4_col7, #T_f1e54_row7_col4 {
#   background-color: #a7b6ce;
#   color: #000000;
# }
# #T_f1e54_row4_col8, #T_f1e54_row8_col4 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_f1e54_row4_col9, #T_f1e54_row9_col4 {
#   background-color: #e8cac8;
#   color: #000000;
# }
# #T_f1e54_row5_col7, #T_f1e54_row7_col5 {
#   background-color: #faf2f1;
#   color: #000000;
# }
# #T_f1e54_row5_col8, #T_f1e54_row8_col5 {
#   background-color: #f7f4f4;
#   color: #000000;
# }
# #T_f1e54_row6_col7, #T_f1e54_row7_col6 {
#   background-color: #f3e2e0;
#   color: #000000;
# }
# #T_f1e54_row6_col9, #T_f1e54_row9_col6 {
#   background-color: #95a9c8;
#   color: #f1f1f1;
# }
# #T_f1e54_row7_col9, #T_f1e54_row9_col7 {
#   background-color: #d1918e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f1e54">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1e54_level0_col0" class="col_heading level0 col0" >row_id</th>
#       <th id="T_f1e54_level0_col1" class="col_heading level0 col1" >timestamp</th>
#       <th id="T_f1e54_level0_col2" class="col_heading level0 col2" >user_id</th>
#       <th id="T_f1e54_level0_col3" class="col_heading level0 col3" >content_id</th>
#       <th id="T_f1e54_level0_col4" class="col_heading level0 col4" >content_type_id</th>
#       <th id="T_f1e54_level0_col5" class="col_heading level0 col5" >task_container_id</th>
#       <th id="T_f1e54_level0_col6" class="col_heading level0 col6" >user_answer</th>
#       <th id="T_f1e54_level0_col7" class="col_heading level0 col7" >answered_correctly</th>
#       <th id="T_f1e54_level0_col8" class="col_heading level0 col8" >prior_question_elapsed_time</th>
#       <th id="T_f1e54_level0_col9" class="col_heading level0 col9" >cor_ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1e54_level0_row0" class="row_heading level0 row0" >row_id</th>
#       <td id="T_f1e54_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f1e54_row0_col1" class="data row0 col1" >-0.000843</td>
#       <td id="T_f1e54_row0_col2" class="data row0 col2" >0.999057</td>
#       <td id="T_f1e54_row0_col3" class="data row0 col3" >-0.006783</td>
#       <td id="T_f1e54_row0_col4" class="data row0 col4" >0.004011</td>
#       <td id="T_f1e54_row0_col5" class="data row0 col5" >-0.071142</td>
#       <td id="T_f1e54_row0_col6" class="data row0 col6" >-0.002382</td>
#       <td id="T_f1e54_row0_col7" class="data row0 col7" >-0.015589</td>
#       <td id="T_f1e54_row0_col8" class="data row0 col8" >0.016242</td>
#       <td id="T_f1e54_row0_col9" class="data row0 col9" >-0.009094</td>
#     </tr>
#     <tr>
#       <th id="T_f1e54_level0_row1" class="row_heading level0 row1" >timestamp</th>
#       <td id="T_f1e54_row1_col0" class="data row1 col0" >-0.000843</td>
#       <td id="T_f1e54_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_f1e54_row1_col2" class="data row1 col2" >-0.001041</td>
#       <td id="T_f1e54_row1_col3" class="data row1 col3" >0.032189</td>
#       <td id="T_f1e54_row1_col4" class="data row1 col4" >0.007441</td>
#       <td id="T_f1e54_row1_col5" class="data row1 col5" >0.364525</td>
#       <td id="T_f1e54_row1_col6" class="data row1 col6" >-0.001796</td>
#       <td id="T_f1e54_row1_col7" class="data row1 col7" >0.027571</td>
#       <td id="T_f1e54_row1_col8" class="data row1 col8" >0.016144</td>
#       <td id="T_f1e54_row1_col9" class="data row1 col9" >0.032882</td>
#     </tr>
#     <tr>
#       <th id="T_f1e54_level0_row2" class="row_heading level0 row2" >user_id</th>
#       <td id="T_f1e54_row2_col0" class="data row2 col0" >0.999057</td>
#       <td id="T_f1e54_row2_col1" class="data row2 col1" >-0.001041</td>
#       <td id="T_f1e54_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_f1e54_row2_col3" class="data row2 col3" >-0.007103</td>
#       <td id="T_f1e54_row2_col4" class="data row2 col4" >0.004102</td>
#       <td id="T_f1e54_row2_col5" class="data row2 col5" >-0.072862</td>
#       <td id="T_f1e54_row2_col6" class="data row2 col6" >-0.002361</td>
#       <td id="T_f1e54_row2_col7" class="data row2 col7" >-0.014776</td>
#       <td id="T_f1e54_row2_col8" class="data row2 col8" >0.016981</td>
#       <td id="T_f1e54_row2_col9" class="data row2 col9" >-0.008364</td>
#     </tr>
#     <tr>
#       <th id="T_f1e54_level0_row3" class="row_heading level0 row3" >content_id</th>
#       <td id="T_f1e54_row3_col0" class="data row3 col0" >-0.006783</td>
#       <td id="T_f1e54_row3_col1" class="data row3 col1" >0.032189</td>
#       <td id="T_f1e54_row3_col2" class="data row3 col2" >-0.007103</td>
#       <td id="T_f1e54_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_f1e54_row3_col4" class="data row3 col4" >0.420121</td>
#       <td id="T_f1e54_row3_col5" class="data row3 col5" >0.062908</td>
#       <td id="T_f1e54_row3_col6" class="data row3 col6" >-0.110374</td>
#       <td id="T_f1e54_row3_col7" class="data row3 col7" >-0.203327</td>
#       <td id="T_f1e54_row3_col8" class="data row3 col8" >0.149778</td>
#       <td id="T_f1e54_row3_col9" class="data row3 col9" >0.080741</td>
#     </tr>
#     <tr>
#       <th id="T_f1e54_level0_row4" class="row_heading level0 row4" >content_type_id</th>
#       <td id="T_f1e54_row4_col0" class="data row4 col0" >0.004011</td>
#       <td id="T_f1e54_row4_col1" class="data row4 col1" >0.007441</td>
#       <td id="T_f1e54_row4_col2" class="data row4 col2" >0.004102</td>
#       <td id="T_f1e54_row4_col3" class="data row4 col3" >0.420121</td>
#       <td id="T_f1e54_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_f1e54_row4_col5" class="data row4 col5" >-0.013024</td>
#       <td id="T_f1e54_row4_col6" class="data

# %%
# Удаляем ненужные столбцы, явно не связанные со столбцом успеваемости
df_corr.drop(df_corr.columns[[0, 1, 2, 3, 5, 8]], axis = 1, inplace = True)
# Выведем обновлённую корреляцию числовых признаков
df_corr.corr().style.background_gradient(cmap = cm, vmin = -1, vmax = 1)
# Out:
# <style type="text/css">
# #T_b505a_row0_col0, #T_b505a_row1_col1, #T_b505a_row2_col2, #T_b505a_row3_col3 {
#   background-color: #a9373b;
#   color: #f1f1f1;
# }
# #T_b505a_row0_col1, #T_b505a_row1_col0 {
#   background-color: #c7cedc;
#   color: #000000;
# }
# #T_b505a_row0_col2, #T_b505a_row2_col0 {
#   background-color: #a7b6ce;
#   color: #000000;
# }
# #T_b505a_row0_col3, #T_b505a_row3_col0 {
#   background-color: #e8cac8;
#   color: #000000;
# }
# #T_b505a_row1_col2, #T_b505a_row2_col1 {
#   background-color: #f3e2e0;
#   color: #000000;
# }
# #T_b505a_row1_col3, #T_b505a_row3_col1 {
#   background-color: #95a9c8;
#   color: #f1f1f1;
# }
# #T_b505a_row2_col3, #T_b505a_row3_col2 {
#   background-color: #d1918e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b505a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b505a_level0_col0" class="col_heading level0 col0" >content_type_id</th>
#       <th id="T_b505a_level0_col1" class="col_heading level0 col1" >user_answer</th>
#       <th id="T_b505a_level0_col2" class="col_heading level0 col2" >answered_correctly</th>
#       <th id="T_b505a_level0_col3" class="col_heading level0 col3" >cor_ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b505a_level0_row0" class="row_heading level0 row0" >content_type_id</th>
#       <td id="T_b505a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b505a_row0_col1" class="data row0 col1" >-0.283418</td>
#       <td id="T_b505a_row0_col2" class="data row0 col2" >-0.438788</td>
#       <td id="T_b505a_row0_col3" class="data row0 col3" >0.249123</td>
#     </tr>
#     <tr>
#       <th id="T_b505a_level0_row1" class="row_heading level0 row1" >user_answer</th>
#       <td id="T_b505a_row1_col0" class="data row1 col0" >-0.283418</td>
#       <td id="T_b505a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b505a_row1_col2" class="data row1 col2" >0.126721</td>
#       <td id="T_b505a_row1_col3" class="data row1 col3" >-0.527333</td>
#     </tr>
#     <tr>
#       <th id="T_b505a_level0_row2" class="row_heading level0 row2" >answered_correctly</th>
#       <td id="T_b505a_row2_col0" class="data row2 col0" >-0.438788</td>
#       <td id="T_b505a_row2_col1" class="data row2 col1" >0.126721</td>
#       <td id="T_b505a_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b505a_row2_col3" class="data row2 col3" >0.531547</td>
#     </tr>
#     <tr>
#       <th id="T_b505a_level0_row3" class="row_heading level0 row3" >cor_ratio</th>
#       <td id="T_b505a_row3_col0" class="data row3 col0" >0.249123</td>
#       <td id="T_b505a_row3_col1" class="data row3 col1" >-0.527333</td>
#       <td id="T_b505a_row3_col2" class="data row3 col2" >0.531547</td>
#       <td id="T_b505a_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### По представленной корреляции числовых признаков видно, что помимо исходных для неё признаков успеваемость слабо зависит от типа контента (вопрос или лекция).

# %%
df.agg({'user_id': pd.Series.nunique}) # ищем кол-во уникальных идентификаторов студента
# Out:
# user_id    3824
# dtype: int64

# %%
# Группируем общее кол-во ответов и кол-во правильных ответов каждого студента по его идентификатору в датафрейм us_a
us_a = df[['user_id', 'user_answer', 'answered_correctly']].groupby(['user_id'], as_index = False).sum()
us_a.head()
# Out:
#    user_id  user_answer  answered_correctly
# 0      115           72                  32
# 1      124           49                   7
# 2     2746           31                  10
# 3     5382          169                  81
# 4     8623          149                  67

# %%
us_a.describe() # выводим статистику ответов студентов
# Out:
#             user_id   user_answer  answered_correctly
# count  3.824000e+03   3824.000000         3824.000000
# mean   1.050633e+07    359.514644          161.481172
# std    5.958653e+06    984.492304          457.802761
# min    1.150000e+02      1.000000           -2.000000
# 25%    5.363199e+06     38.000000           11.000000
# 50%    1.061051e+07     60.000000           23.000000
# 75%    1.565077e+07    219.000000           94.000000
# max    2.094902e+07  16907.000000         6103.000000

# %%
# Сокращаем разброс количества ответов студентов
def rem_emission(df, col, k_std): # задаём функцию сокращения разброса ответов
        mean = df[col].mean() # среднее значение переданного столбца col
        std_o = df[col].std() # стандартное отклонение переданного столбца col
        return df[(df[col] <= mean + (k_std * std_o))]

us_a = rem_emission(us_a, 'user_answer', 1) # вызываем функцию сокращения разброса ответов
# Добавляем столбец cor_ratio успеваемости (соотношения кол-ва правильных ответов к общему кол-ву ответов студентов)
us_a['cor_ratio'] = us_a.answered_correctly / us_a.user_answer
us_a # выводим первые 5 и последние 5 строк полученного датафрейма us_a
# Out:
#        user_id  user_answer  answered_correctly  cor_ratio
# 0          115           72                  32   0.444444
# 1          124           49                   7   0.142857
# 2         2746           31                  10   0.322581
# 3         5382          169                  81   0.479290
# 4         8623          149                  67   0.449664
# ...        ...          ...                 ...        ...
# 3819  20913319          575                 233   0.405217
# 3820  20913864           20                   7   0.350000
# 3821  20938253          739                 308   0.416779
# 3822  20948951           78                  31   0.397436
# 3823  20949024           71                  15   0.211268
#
# [3585 rows x 4 columns]

# %%
us_a.describe() # выводим статистику ответов студентов с новым столбцом
# Out:
#             user_id  user_answer  answered_correctly    cor_ratio
# count  3.585000e+03  3585.000000         3585.000000  3585.000000
# mean   1.052197e+07   159.402789           68.483682     0.383755
# std    5.961041e+06   238.836485          111.890436     0.131749
# min    1.150000e+02     1.000000           -2.000000    -0.017241
# 25%    5.386918e+06    36.000000           11.000000     0.293103
# 50%    1.062930e+07    55.000000           21.000000     0.392857
# 75%    1.568217e+07   151.000000           66.000000     0.472603
# max    2.094902e+07  1335.000000          759.000000     1.500000

# %% [markdown]
# ### Вычисляем медианное значение количества ответов студентов

# %%
a_per_user_med = us_a.user_answer.median()
print('Медианное значение количества ответов студентов: ', a_per_user_med)
# Out:
# Медианное значение количества ответов студентов:  55.0

# %% [markdown]
# ### Визуализируем данные о количестве ответов студентов

# %%
# Выводим распределение кол-ва ответов студентов: заметен перекос в начале
sns.histplot(data = us_a, x = 'user_answer')
# Out:
# <AxesSubplot: xlabel='user_answer', ylabel='Count'>

# %%
sns.histplot(data = us_a, x = 'user_answer', log_scale = True) # нормализуем кол-во ответов студентов
# Out:
# <AxesSubplot: xlabel='user_answer', ylabel='Count'>

# %%
# Выводим распределение кол-ва ответов студентов, которое больше медианного
print(us_a.query('user_answer > 55')['cor_ratio'].median())
us_a.query('user_answer > 55')['cor_ratio'].hist(bins = 50)
# Out:
# 0.42857142857142855
# <AxesSubplot: >

# %%
# Выводим распределение кол-ва ответов студентов, которое больше 75%
print(us_a.query('user_answer > 151')['cor_ratio'].median())
us_a.query('user_answer > 151')['cor_ratio'].hist(bins = 50)
# Out:
# 0.4507042253521127
# <AxesSubplot: >

# %%
# Выводим распределение кол-ва ответов студентов, которое больше 500
print(us_a.query('user_answer > 500')['cor_ratio'].median())
us_a.query('user_answer > 500')['cor_ratio'].hist(bins = 50)
# Out:
# 0.4578313253012048
# <AxesSubplot: >

# %%
# Выводим распределение кол-ва ответов студентов, которое меньше 50
print(us_a.query('user_answer > 50')['cor_ratio'].median())
us_a.query('user_answer > 50')['cor_ratio'].hist(bins = 50)
# Out:
# 0.42436974789915966
# <AxesSubplot: >

# %% [markdown]
# #### По представленным графикам видно, что студенты, ответившие на меньше медианного значения количества ответов, справлялись хуже тех, кто ответил больше медианного значения. При этом ответы в количестве гораздо большем медианного значения незначительно сказалось на увеличении числа правильных ответов.

# %% [markdown]
# ## Поищем взаимосвязь времени между взаимодействием со студентом и завершением первого события от него, среднего времени ответа на каждый вопрос и количества правильных ответов с общим количеством ответов студентов

# %%
# Группируем общее кол-во ответов, кол-во правильных ответов и время ответа 
# на каждый вопрос студентов по их идентификаторам в датафрейм corr_look
corr_look = df[['user_id', 'user_answer', 'answered_correctly', 'timestamp', \
    'prior_question_elapsed_time']].groupby(['user_id'], as_index = False).sum()
# Добавляем столбец timestamp_ratio соотношения времени между взаимодействием со студентом 
# и завершением первого события от него к общему кол-ву ответов студентов
corr_look['timestamp_ratio'] = corr_look['timestamp'] / corr_look['user_answer']
# Добавляем столбец elapsed_time_ratio соотношения среднего времени ответа на каждый вопрос к общему кол-ву ответов студентов
corr_look['elapsed_time_ratio'] = corr_look['prior_question_elapsed_time'] / corr_look['user_answer']
# Добавляем столбец cor_ratio успеваемости (соотношения кол-ва правильных ответов к общему кол-ву ответов студентов)
corr_look['cor_ratio'] = corr_look.answered_correctly / corr_look.user_answer
# Удаляем ненужные столбцы
corr_look.drop(corr_look.columns[[0, 2, 3, 4]], axis = 1, inplace = True)
corr_look = rem_emission(corr_look, 'user_answer', 1) # вызываем функцию сокращения разброса ответов
corr_look # выводим первые 5 и последние 5 строк полученного датафрейма corr_look
# Out:
#       user_answer  timestamp_ratio  elapsed_time_ratio  cor_ratio
# 0              72     6.524638e+07        12458.319444   0.444444
# 1              49     2.252203e+05        11122.387755   0.142857
# 2              31     2.472123e+05        10483.870968   0.322581
# 3             169     2.879101e+08        26449.704142   0.479290
# 4             149     2.615750e+08        18923.489933   0.449664
# ...           ...              ...                 ...        ...
# 3819          575     7.238333e+08        19102.003478   0.405217
# 3820           20     3.388405e+05        18200.000000   0.350000
# 3821          739     1.787103e+08        16015.966171   0.416779
# 3822           78     1.462367e+09        12730.769231   0.397436
# 3823           71     7.114120e+06        21684.225352   0.211268
#
# [3585 rows x 4 columns]

# %%
# Ещё раз убеждаемся в отсутствии явной связи между успеваемостью и кол-вом ответов студентов
# Out:
# <AxesSubplot: xlabel='user_answer', ylabel='cor_ratio'>

# %%
# Выводим соотношение timestamp_ratio к кол-ву ответов студентов: явной связи не видно
sns.regplot(data = corr_look, x = 'user_answer', y = 'timestamp_ratio')
# Out:
# <AxesSubplot: xlabel='user_answer', ylabel='timestamp_ratio'>

# %%
# Выводим соотношение elapsed_time_ratio к кол-ву ответов студентов: явной связи не видно
sns.regplot(data = corr_look, x = 'user_answer', y = 'elapsed_time_ratio')
# Out:
# <AxesSubplot: xlabel='user_answer', ylabel='elapsed_time_ratio'>

# %%
# Выводим соотношение timestamp_ratio к успеваемости: явной связи не видно
sns.regplot(data = corr_look, x = 'timestamp_ratio', y = 'cor_ratio')
# Out:
# <AxesSubplot: xlabel='timestamp_ratio', ylabel='cor_ratio'>

# %%
# Есть небольшая связь между elapsed_time_ratio и успеваемостью
sns.regplot(data = corr_look, x = 'elapsed_time_ratio', y = 'cor_ratio')
# Out:
# <AxesSubplot: xlabel='elapsed_time_ratio', ylabel='cor_ratio'>

# %% [markdown]
# ## Итак, на успеваемость студентов влияют следующие характеристики:
# - количество ответов студентов, большее медианного значения количества ответов, равного 55
# - типа контента (вопрос или лекция) - очень слабо
# - соотношения количества правильных ответов и среднего времени ответа на каждый вопрос к общему количеству ответов студентов - слабо
